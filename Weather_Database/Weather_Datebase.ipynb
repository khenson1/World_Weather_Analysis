# %%
#Import dependicies
import pandas as pd
import numpy as np
from citipy import citipy 
import gmaps
import requests
from NewConfig import weather_api_key

# %%
#Create a set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
longs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_longs = zip(lats, longs)
lat_longs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_longs)

# %%
#Get the nearest city using the citipy module
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in new_cities:
        cities.append(city)
len(cities)
# Out:
# 515

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=42be8636db0fcb7f1ec0e7fc3e2125ba

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_country = city_weather["sys"]["country"]
        city_long = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Long": city_long,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

for i in range(len(new_cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    new_city_url = new_url + "&q=" + citites[i]
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kupang
# Processing Record 2 of Set 1 | menongue
# Processing Record 3 of Set 1 | ust-nera
# Processing Record 4 of Set 1 | shirak
# Processing Record 5 of Set 1 | biloela
# Processing Record 6 of Set 1 | tulagi
# Processing Record 7 of Set 1 | ihosy
# Processing Record 8 of Set 1 | paita
# Processing Record 9 of Set 1 | vanderhoof
# Processing Record 10 of Set 1 | maragogi
# Processing Record 11 of Set 1 | marsa matruh
# Processing Record 12 of Set 1 | kashi
# Processing Record 13 of Set 1 | langarud
# Processing Record 14 of Set 1 | isangel
# Processing Record 15 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 1 | ormara
# Processing Record 17 of Set 1 | kungurtug
# Processing Record 18 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 19 of Set 1 | svobodnyy
# Processing Record 20 of Set 1 | bayshore gardens
# Processing Record 21 of Set 1 | yeppoon
# Processing Record 22 of Set 1 | aguimes
# Processing Record 23 of Set 1 | grahamstown
# Processing Record 24 of Set 1 | nizhniy odes
# Processing Record 25 of Set 1 | tambovka
# Processing Record 26 of Set 1 | les cayes
# Processing Record 27 of Set 1 | isangel
# Processing Record 28 of Set 1 | ardabil
# Processing Record 29 of Set 1 | bayanday
# Processing Record 30 of Set 1 | manzil salim
# Processing Record 31 of Set 1 | ormara
# Processing Record 32 of Set 1 | marsabit
# Processing Record 33 of Set 1 | banepa
# Processing Record 34 of Set 1 | almora
# Processing Record 35 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 1 | sibolga
# Processing Record 37 of Set 1 | bokoro
# Processing Record 38 of Set 1 | shalakusha
# Processing Record 39 of Set 1 | middleton
# Processing Record 40 of Set 1 | bundaberg
# Processing Record 41 of Set 1 | dingle
# Processing Record 42 of Set 1 | usinsk
# Processing Record 43 of Set 1 | moron
# Processing Record 44 of Set 1 | inirida
# Processing Record 45 of Set 1 | marana
# Processing Record 46 of Set 1 | binucayan
# Processing Record 47 of Set 1 | marsh harbour
# Processing Record 48 of Set 1 | korem
# Processing Record 49 of Set 1 | tucuma
# Processing Record 50 of Set 1 | fraserburgh
# Processing Record 1 of Set 2 | ewa beach
# Processing Record 2 of Set 2 | zdvinsk
# Processing Record 3 of Set 2 | saint-joseph
# Processing Record 4 of Set 2 | taraz
# Processing Record 5 of Set 2 | quibdo
# Processing Record 6 of Set 2 | senj
# Processing Record 7 of Set 2 | sterling
# Processing Record 8 of Set 2 | igrim
# Processing Record 9 of Set 2 | george
# Processing Record 10 of Set 2 | takoradi
# Processing Record 11 of Set 2 | yelizovo
# Processing Record 12 of Set 2 | aksarayskiy
# Processing Record 13 of Set 2 | chicama
# Processing Record 14 of Set 2 | dalvik
# Processing Record 15 of Set 2 | gorontalo
# Processing Record 16 of Set 2 | maryville
# Processing Record 17 of Set 2 | la sarre
# Processing Record 18 of Set 2 | novogornyy
# Processing Record 19 of Set 2 | kloulklubed
# Processing Record 20 of Set 2 | sambava
# Processing Record 21 of Set 2 | lerwick
# Processing Record 22 of Set 2 | harnoli
# Processing Record 23 of Set 2 | alice town
# Processing Record 24 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 2 | maceio
# Processing Record 26 of Set 2 | nieves
# Processing Record 27 of Set 2 | luau
# Processing Record 28 of Set 2 | yaan
# Processing Record 29 of Set 2 | muros
# Processing Record 30 of Set 2 | korla
# Processing Record 31 of Set 2 | carlagan
# Processing Record 32 of Set 2 | hualmay
# Processing Record 33 of Set 2 | mujiayingzi
# Processing Record 34 of Set 2 | virginia beach
# Processing Record 35 of Set 2 | catamarca
# Processing Record 36 of Set 2 | mardin
# Processing Record 37 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 38 of Set 2 | aneho
# Processing Record 39 of Set 2 | tuam
# Processing Record 40 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 2 | svetlogorsk
# Processing Record 42 of Set 2 | ketchikan
# Processing Record 43 of Set 2 | bognor regis
# Processing Record 44 of Set 2 | munger
# Processing Record 45 of Set 2 | calama
# Processing Record 46 of Set 2 | kumluca
# Processing Record 47 of Set 2 | glendive
# Processing Record 48 of Set 2 | hue
# Processing Record 49 of Set 2 | camopi
# Processing Record 50 of Set 2 | luziania
# Processing Record 1 of Set 3 | cururupu
# Processing Record 2 of Set 3 | tselinnoye
# Processing Record 3 of Set 3 | havelock
# Processing Record 4 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 3 | waipawa
# Processing Record 6 of Set 3 | dingle
# Processing Record 7 of Set 3 | xinyang
# Processing Record 8 of Set 3 | cambre
# Processing Record 9 of Set 3 | evensk
# Processing Record 10 of Set 3 | talaya
# Processing Record 11 of Set 3 | dodge city
# Processing Record 12 of Set 3 | aksay
# Processing Record 13 of Set 3 | bilma
# Processing Record 14 of Set 3 | xichang
# Processing Record 15 of Set 3 | kumluca
# Processing Record 16 of Set 3 | tongchuan
# Processing Record 17 of Set 3 | berdigestyakh
# Processing Record 18 of Set 3 | flinders
# Processing Record 19 of Set 3 | nalut
# Processing Record 20 of Set 3 | caraballeda
# Processing Record 21 of Set 3 | andahuaylas
# Processing Record 22 of Set 3 | rosario
# Processing Record 23 of Set 3 | meulaboh
# Processing Record 24 of Set 3 | jaffna
# Processing Record 25 of Set 3 | boguchany
# Processing Record 26 of Set 3 | thayetmyo
# Processing Record 27 of Set 3 | hearst
# Processing Record 28 of Set 3 | deputatskiy
# Processing Record 29 of Set 3 | penzance
# Processing Record 30 of Set 3 | boa vista
# Processing Record 31 of Set 3 | bilma
# Processing Record 32 of Set 3 | christchurch
# Processing Record 33 of Set 3 | batemans bay
# Processing Record 34 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 3 | seryshevo
# Processing Record 36 of Set 3 | benjamin hill
# Processing Record 37 of Set 3 | puerto del rosario
# Processing Record 38 of Set 3 | crotone
# Processing Record 39 of Set 3 | gumia
# Processing Record 40 of Set 3 | quballat
# Processing Record 41 of Set 3 | taperoa
# Processing Record 42 of Set 3 | yaring
# Processing Record 43 of Set 3 | superior
# Processing Record 44 of Set 3 | lerwick
# Processing Record 45 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 3 | akyab
# Processing Record 47 of Set 3 | qaqortoq
# Processing Record 48 of Set 3 | flinders
# Processing Record 49 of Set 3 | trincomalee
# Processing Record 50 of Set 3 | pedernales
# Processing Record 1 of Set 4 | gazojak
# Processing Record 2 of Set 4 | bhindar
# Processing Record 3 of Set 4 | vigrestad
# Processing Record 4 of Set 4 | sambava
# Processing Record 5 of Set 4 | mecca
# Processing Record 6 of Set 4 | dingle
# Processing Record 7 of Set 4 | lima
# Processing Record 8 of Set 4 | zapolyarnyy
# Processing Record 9 of Set 4 | coffs harbour
# Processing Record 10 of Set 4 | baykit
# Processing Record 11 of Set 4 | acajutla
# Processing Record 12 of Set 4 | lahat
# Processing Record 13 of Set 4 | imperia
# Processing Record 14 of Set 4 | evensk
# Processing Record 15 of Set 4 | san carlos del zulia
# Processing Record 16 of Set 4 | boguchany
# Processing Record 17 of Set 4 | chipiona
# Processing Record 18 of Set 4 | luganville
# Processing Record 19 of Set 4 | jiayuguan
# Processing Record 20 of Set 4 | casas grandes
# Processing Record 21 of Set 4 | ajaccio
# Processing Record 22 of Set 4 | palmeiras de goias
# Processing Record 23 of Set 4 | khuzhir
# Processing Record 24 of Set 4 | pandan
# Processing Record 25 of Set 4 | iracoubo
# Processing Record 26 of Set 4 | anaco
# Processing Record 27 of Set 4 | kidal
# Processing Record 28 of Set 4 | tevaitoa
# Processing Record 29 of Set 4 | qasigiannguit
# Processing Record 30 of Set 4 | sept-iles
# Processing Record 31 of Set 4 | isangel
# Processing Record 32 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 4 | batangafo
# Processing Record 34 of Set 4 | pokaran
# Processing Record 35 of Set 4 | nicoya
# Processing Record 36 of Set 4 | santa ines
# Processing Record 37 of Set 4 | smiths falls
# Processing Record 38 of Set 4 | raton
# Processing Record 39 of Set 4 | golden
# Processing Record 40 of Set 4 | prince george
# Processing Record 41 of Set 4 | sault sainte marie
# Processing Record 42 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 43 of Set 4 | chifeng
# Processing Record 44 of Set 4 | rio gallegos
# Processing Record 45 of Set 4 | keffi
# Processing Record 46 of Set 4 | lucapa
# Processing Record 47 of Set 4 | rio gallegos
# Processing Record 48 of Set 4 | ikwiriri
# Processing Record 49 of Set 4 | aitape
# Processing Record 50 of Set 4 | domoni
# Processing Record 1 of Set 5 | nalut
# Processing Record 2 of Set 5 | guanica
# Processing Record 3 of Set 5 | bozoum
# Processing Record 4 of Set 5 | fargo
# Processing Record 5 of Set 5 | vieques
# Processing Record 6 of Set 5 | athabasca
# Processing Record 7 of Set 5 | dingle
# Processing Record 8 of Set 5 | sehithwa
# Processing Record 9 of Set 5 | yarada
# Processing Record 10 of Set 5 | bisho
# Processing Record 11 of Set 5 | qasigiannguit
# Processing Record 12 of Set 5 | liverpool
# Processing Record 13 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 14 of Set 5 | kangaatsiaq
# Processing Record 15 of Set 5 | puerto salgar
# Processing Record 16 of Set 5 | orsha
# Processing Record 17 of Set 5 | chicama
# Processing Record 18 of Set 5 | verkhniy baskunchak
# Processing Record 19 of Set 5 | talcahuano
# Processing Record 20 of Set 5 | nikolayevsk-na-amure
# Processing Record 21 of Set 5 | umm ruwabah
# City not found. Skipping...
# Processing Record 22 of Set 5 | jijiga
# Processing Record 23 of Set 5 | vila do maio
# Processing Record 24 of Set 5 | aasiaat
# Processing Record 25 of Set 5 | pozo colorado
# Processing Record 26 of Set 5 | monrovia
# Processing Record 27 of Set 5 | itabirito
# Processing Record 28 of Set 5 | phan thiet
# Processing Record 29 of Set 5 | sampit
# Processing Record 30 of Set 5 | zwedru
# Processing Record 31 of Set 5 | tahta
# Processing Record 32 of Set 5 | galway
# Processing Record 33 of Set 5 | neiafu
# Processing Record 34 of Set 5 | deputatskiy
# Processing Record 35 of Set 5 | zorritos
# Processing Record 36 of Set 5 | mweka
# Processing Record 37 of Set 5 | behbahan
# Processing Record 38 of Set 5 | wajima
# Processing Record 39 of Set 5 | keti bandar
# Processing Record 40 of Set 5 | nanhai
# Processing Record 41 of Set 5 | aldan
# Processing Record 42 of Set 5 | marabba
# Processing Record 43 of Set 5 | madimba
# Processing Record 44 of Set 5 | olyka
# Processing Record 45 of Set 5 | solnechnyy
# Processing Record 46 of Set 5 | panzhihua
# Processing Record 47 of Set 5 | coihaique
# Processing Record 48 of Set 5 | cocula
# Processing Record 49 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 50 of Set 5 | kedrovyy
# Processing Record 1 of Set 6 | ayorou
# Processing Record 2 of Set 6 | savinka
# Processing Record 3 of Set 6 | nata
# Processing Record 4 of Set 6 | khani
# Processing Record 5 of Set 6 | biloela
# Processing Record 6 of Set 6 | yatou
# Processing Record 7 of Set 6 | manyana
# Processing Record 8 of Set 6 | colac
# Processing Record 9 of Set 6 | cheremukhovo
# Processing Record 10 of Set 6 | istanbul
# Processing Record 11 of Set 6 | emmett
# Processing Record 12 of Set 6 | bakchar
# Processing Record 13 of Set 6 | manono
# Processing Record 14 of Set 6 | cochrane
# Processing Record 15 of Set 6 | gornopravdinsk
# Processing Record 16 of Set 6 | mecca
# Processing Record 17 of Set 6 | sangueya
# Processing Record 18 of Set 6 | disna
# Processing Record 19 of Set 6 | worthington
# Processing Record 20 of Set 6 | belyy yar
# Processing Record 21 of Set 6 | jinchang
# Processing Record 22 of Set 6 | shuangyang
# Processing Record 23 of Set 6 | wufeng
# Processing Record 24 of Set 6 | mazyr
# Processing Record 25 of Set 6 | margate
# Processing Record 26 of Set 6 | kangundo
# Processing Record 27 of Set 6 | hernani
# Processing Record 28 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 6 | waipawa
# Processing Record 30 of Set 6 | sayyan
# Processing Record 31 of Set 6 | samana
# Processing Record 32 of Set 6 | gorontalo
# Processing Record 33 of Set 6 | thinadhoo
# Processing Record 34 of Set 6 | cassilandia
# Processing Record 35 of Set 6 | cali
# Processing Record 36 of Set 6 | jardim
# Processing Record 37 of Set 6 | vestmanna
# Processing Record 38 of Set 6 | pitimbu
# Processing Record 39 of Set 6 | miranda
# Processing Record 40 of Set 6 | severo-yeniseyskiy
# Processing Record 41 of Set 6 | chegdomyn
# Processing Record 42 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 6 | rhyl
# Processing Record 44 of Set 6 | den helder
# Processing Record 45 of Set 6 | abiy adi
# City not found. Skipping...
# Processing Record 46 of Set 6 | san ramon
# Processing Record 47 of Set 6 | arman
# Processing Record 48 of Set 6 | orsha
# Processing Record 49 of Set 6 | balaipungut
# Processing Record 50 of Set 6 | lavumisa
# Processing Record 1 of Set 7 | uribia
# Processing Record 2 of Set 7 | sungaipenuh
# Processing Record 3 of Set 7 | pyu
# Processing Record 4 of Set 7 | filadelfia
# Processing Record 5 of Set 7 | nemuro
# Processing Record 6 of Set 7 | yeppoon
# Processing Record 7 of Set 7 | lima
# Processing Record 8 of Set 7 | praya
# Processing Record 9 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 7 | juegang
# Processing Record 11 of Set 7 | itupiranga
# Processing Record 12 of Set 7 | bonthe
# Processing Record 13 of Set 7 | zell am see
# Processing Record 14 of Set 7 | sao raimundo das mangabeiras
# Processing Record 15 of Set 7 | sangar
# Processing Record 16 of Set 7 | eucaliptus
# Processing Record 17 of Set 7 | pandan
# Processing Record 18 of Set 7 | arshan
# Processing Record 19 of Set 7 | manzhouli
# Processing Record 20 of Set 7 | meiktila
# Processing Record 21 of Set 7 | kholmy
# Processing Record 22 of Set 7 | wuxue
# Processing Record 23 of Set 7 | korla
# Processing Record 24 of Set 7 | byron bay
# Processing Record 25 of Set 7 | jizan
# Processing Record 26 of Set 7 | ropcha
# Processing Record 27 of Set 7 | jiblah
# Processing Record 28 of Set 7 | altamira
# Processing Record 29 of Set 7 | haradok
# Processing Record 30 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 31 of Set 7 | dawei
# Processing Record 32 of Set 7 | artvin
# Processing Record 33 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 7 | zeya
# Processing Record 35 of Set 7 | berezovyy
# Processing Record 36 of Set 7 | diego de almagro
# Processing Record 37 of Set 7 | biltine
# Processing Record 38 of Set 7 | mariental
# Processing Record 39 of Set 7 | nuziders
# Processing Record 40 of Set 7 | phonhong
# Processing Record 41 of Set 7 | san jeronimo
# Processing Record 42 of Set 7 | piacabucu
# Processing Record 43 of Set 7 | berdigestyakh
# Processing Record 44 of Set 7 | waipawa
# Processing Record 45 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 46 of Set 7 | meiganga
# Processing Record 47 of Set 7 | tilichiki
# Processing Record 48 of Set 7 | rocha
# Processing Record 49 of Set 7 | akyab
# Processing Record 50 of Set 7 | acajutla
# Processing Record 1 of Set 8 | kodinsk
# Processing Record 2 of Set 8 | dillon
# Processing Record 3 of Set 8 | japura
# Processing Record 4 of Set 8 | manavalakurichi
# Processing Record 5 of Set 8 | carbonia
# Processing Record 6 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 7 of Set 8 | warrnambool
# Processing Record 8 of Set 8 | dingle
# Processing Record 9 of Set 8 | matagami
# Processing Record 10 of Set 8 | plougastel-daoulas
# Processing Record 11 of Set 8 | kardamaina
# Processing Record 12 of Set 8 | villa oliva
# City not found. Skipping...
# Processing Record 13 of Set 8 | nynashamn
# Processing Record 14 of Set 8 | lamu
# Processing Record 15 of Set 8 | kichera
# Processing Record 16 of Set 8 | teguldet
# Processing Record 17 of Set 8 | gampola
# Processing Record 18 of Set 8 | mandalgovi
# Processing Record 19 of Set 8 | lamu
# Processing Record 20 of Set 8 | kirakira
# Processing Record 21 of Set 8 | otradnoye
# Processing Record 22 of Set 8 | nehe
# Processing Record 23 of Set 8 | iralaya
# Processing Record 24 of Set 8 | xining
# Processing Record 25 of Set 8 | mao
# Processing Record 26 of Set 8 | mirnyy
# Processing Record 27 of Set 8 | kuusamo
# Processing Record 28 of Set 8 | big bend
# Processing Record 29 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 8 | pangody
# Processing Record 31 of Set 8 | savannah bight
# Processing Record 32 of Set 8 | coralville
# Processing Record 33 of Set 8 | neiafu
# Processing Record 34 of Set 8 | sergeyevka
# Processing Record 35 of Set 8 | oyama
# Processing Record 36 of Set 8 | beidao
# Processing Record 37 of Set 8 | flin flon
# Processing Record 38 of Set 8 | ussel
# Processing Record 39 of Set 8 | megion
# Processing Record 40 of Set 8 | seoul
# Processing Record 41 of Set 8 | kourou
# Processing Record 42 of Set 8 | nampula
# Processing Record 43 of Set 8 | guararapes
# Processing Record 44 of Set 8 | seversk
# Processing Record 45 of Set 8 | chon daen
# Processing Record 46 of Set 8 | koupela
# Processing Record 47 of Set 8 | shirokiy
# Processing Record 48 of Set 8 | engels
# Processing Record 49 of Set 8 | pointe michel
# Processing Record 50 of Set 8 | kafr asad
# Processing Record 1 of Set 9 | qaqortoq
# Processing Record 2 of Set 9 | pandan
# Processing Record 3 of Set 9 | caramay
# Processing Record 4 of Set 9 | dyer
# Processing Record 5 of Set 9 | tondon
# Processing Record 6 of Set 9 | montepuez
# Processing Record 7 of Set 9 | juneau
# Processing Record 8 of Set 9 | choix
# Processing Record 9 of Set 9 | tahara
# Processing Record 10 of Set 9 | belaya gora
# Processing Record 11 of Set 9 | terenos
# Processing Record 12 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 9 | monatele
# City not found. Skipping...
# Processing Record 14 of Set 9 | pombas
# Processing Record 15 of Set 9 | north bend
# Processing Record 16 of Set 9 | victoria point
# Processing Record 17 of Set 9 | kulachi
# Processing Record 18 of Set 9 | volkhov
# Processing Record 19 of Set 9 | arona
# Processing Record 20 of Set 9 | luangwa
# Processing Record 21 of Set 9 | puerto baquerizo moreno
# Processing Record 22 of Set 9 | morant bay
# Processing Record 23 of Set 9 | dingle
# Processing Record 24 of Set 9 | phnum penh
# City not found. Skipping...
# Processing Record 25 of Set 9 | amapa
# Processing Record 26 of Set 9 | bandar-e anzali
# Processing Record 27 of Set 9 | sola
# Processing Record 28 of Set 9 | araouane
# Processing Record 29 of Set 9 | fayetteville
# Processing Record 30 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 31 of Set 9 | vawkavysk
# Processing Record 32 of Set 9 | santa cecilia
# Processing Record 33 of Set 9 | salta
# Processing Record 34 of Set 9 | barra do garcas
# Processing Record 35 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 36 of Set 9 | muros
# Processing Record 37 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 9 | mbanza-ngungu
# Processing Record 39 of Set 9 | basar
# Processing Record 40 of Set 9 | san vicente
# Processing Record 41 of Set 9 | monster
# Processing Record 42 of Set 9 | gigmoto
# Processing Record 43 of Set 9 | celestun
# Processing Record 44 of Set 9 | pitanga
# Processing Record 45 of Set 9 | qaqortoq
# Processing Record 46 of Set 9 | tilichiki
# Processing Record 47 of Set 9 | gornopravdinsk
# Processing Record 48 of Set 9 | atbasar
# Processing Record 49 of Set 9 | rzhev
# Processing Record 50 of Set 9 | boshnyakovo
# Processing Record 1 of Set 10 | unye
# City not found. Skipping...
# Processing Record 2 of Set 10 | eyl
# Processing Record 3 of Set 10 | marsa matruh
# Processing Record 4 of Set 10 | ndjole
# Processing Record 5 of Set 10 | staraya poltavka
# Processing Record 6 of Set 10 | ivanivka
# Processing Record 7 of Set 10 | odessa
# Processing Record 8 of Set 10 | wadowice
# Processing Record 9 of Set 10 | nueva armenia
# Processing Record 10 of Set 10 | caxias
# Processing Record 11 of Set 10 | ambulu
# Processing Record 12 of Set 10 | ouadda
# Processing Record 13 of Set 10 | hede
# Processing Record 14 of Set 10 | sobolevo
# Processing Record 15 of Set 10 | marsa matruh
# Processing Record 16 of Set 10 | porto belo
# Processing Record 17 of Set 10 | griffith
# Processing Record 18 of Set 10 | enshi
# Processing Record 19 of Set 10 | dali
# Processing Record 20 of Set 10 | yambio
# Processing Record 21 of Set 10 | coos bay
# Processing Record 22 of Set 10 | batemans bay
# Processing Record 23 of Set 10 | tungor
# Processing Record 24 of Set 10 | lamu
# Processing Record 25 of Set 10 | msanga
# Processing Record 26 of Set 10 | chapais
# Processing Record 27 of Set 10 | addi ugri
# City not found. Skipping...
# Processing Record 28 of Set 10 | khasan
# Processing Record 29 of Set 10 | surt
# Processing Record 30 of Set 10 | almenara
# Processing Record 31 of Set 10 | abomey
# Processing Record 32 of Set 10 | filadelfia
# Processing Record 33 of Set 10 | guangyuan
# Processing Record 34 of Set 10 | elizabeth city
# Processing Record 35 of Set 10 | talara
# Processing Record 36 of Set 10 | ananas
# Processing Record 37 of Set 10 | sola
# Processing Record 38 of Set 10 | maragogi
# Processing Record 39 of Set 10 | zhicheng
# Processing Record 40 of Set 10 | la macarena
# Processing Record 41 of Set 10 | teseney
# Processing Record 42 of Set 10 | klyavlino
# Processing Record 43 of Set 10 | the valley
# Processing Record 44 of Set 10 | margate
# Processing Record 45 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 10 | mut
# Processing Record 47 of Set 10 | kayes
# Processing Record 48 of Set 10 | beberibe
# Processing Record 49 of Set 10 | kloulklubed
# Processing Record 50 of Set 10 | khandbari
# Processing Record 1 of Set 11 | paamiut
# Processing Record 2 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 11 | mala
# Processing Record 4 of Set 11 | stykkisholmur
# Processing Record 5 of Set 11 | santa rosa
# Processing Record 6 of Set 11 | fort saint james
# Processing Record 7 of Set 11 | isangel
# Processing Record 8 of Set 11 | mangai
# Processing Record 9 of Set 11 | kenora
# Processing Record 10 of Set 11 | rocha
# Processing Record 11 of Set 11 | glenwood springs
# Processing Record 12 of Set 11 | isangel
# Processing Record 13 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 11 | rio branco
# Processing Record 15 of Set 11 | galle
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-e2597deb01b6> in <module>
#      68
#      69     # Create endpoint URL with each city.
# ---> 70     new_city_url = new_url + "&q=" + citites[i]
#
# NameError: name 'citites' is not defined

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat      Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Kupang -10.1667  123.5833     77.81        89         100        3.62
# 1    Menongue -14.6585   17.6910     64.92        93         100        4.76
# 2    Ust-Nera  64.5667  143.2000     -4.70        99         100        2.39
# 3      Shirak  40.8404   43.9158     17.92        73          20        1.14
# 4     Biloela -24.4167  150.5000     63.90        88         100        7.00
# 5      Tulagi  -9.0996  160.1476     81.95        71          89        2.42
# 6       Ihosy -22.4000   46.1167     67.60        92         100       10.11
# 7       Paita  -5.0892  -81.1144     81.73        65          30       14.52
# 8  Vanderhoof  54.0166 -124.0198     38.39        75         100        3.09
# 9    Maragogi  -9.0122  -35.2225     82.76        71         100       10.51
#
#   Current Description
# 0     overcast clouds
# 1          light rain
# 2     overcast clouds
# 3          few clouds
# 4     overcast clouds
# 5     overcast clouds
# 6     overcast clouds
# 7    scattered clouds
# 8     overcast clouds
# 9     overcast clouds

# %%
# Create the output file(CSV).
output_data_file = "Weather Database/WeatherPy_Database.csv"

#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-129-3c747dab11d4> in <module>
#       3
#       4 #Export the City_Data into a CSV.
# ----> 5 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather Database/WeatherPy_Database.csv'
